# %%
import pandas as pd

url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2020/2020-01-21/spotify_songs.csv"

data = pd.read_csv(url)
data.to_csv('../data/raw/spotify_songs.csv', index=False)

data
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
result = data[(data['valence'] < 0.3) & (data['acousticness'] > 0.7) & (data['duration_ms'] < 240000)]
result = result.head(10)
result
# Out:
#                     track_id                        track_name  \
# 738   5o3pP3SWueoHRCytmwaL52                           caronte
# 771   6JFyoWiWW69dTjPrJ0RxQ1         When You Wish Upon A Star
# 1078  3t87C08isN6yw2DnWOorLm                       Hannah Hunt
# 1096  2IqjKEBiz0CdLKdkXhxw84                        Retrograde
# 1101  5UVBumEwdUnzvqxrXOYLFA                                17
# 1105  65wx71brAmEQz66GXXF8gI                     Sound & Color
# 1116  6HG1JWEbfuf8y1ZhLVq9L3          Don't Wanna Be Your Girl
# 1121  5oK98mpTJSU0iqLHN1hZ3y                    22 (OVER S∞∞N)
# 1124  5zOnoB8FdZudDcPX4O8WqF  (No One Knows Me) Like the Piano
# 1204  6xPVnZ5WcK9sh9FyYIkiW3                           Knowing
#
#          track_artist  track_popularity          track_album_id  \
# 738        Alba Reche                50  5m9csUiQbZ0OSSnVgbeCrQ
# 771         The Mamas                55  0RwaotyCpvAytYj5WaH96L
# 1078  Vampire Weekend                62  2Qi2SySN2ePZwMLDSv9Krn
# ...
